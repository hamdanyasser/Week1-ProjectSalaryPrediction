# %% [markdown]
# # PayScope EDA and Storytelling Plan
#
# Use this notebook to validate the final dashboard story before polishing the Streamlit app.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/ds_salaries.csv')
df.head()

# %%
df.columns.tolist(), df.shape

# %% [markdown]
# ## Story Questions
#
# - What does the overall salary market look like?
# - How does experience affect salary?
# - Which employment setup tends to pay more?
# - Which roles pay more?
# - Which roles have the widest salary spread?
# - How can we explain one prediction in plain English?
